# %%
import importlib
cim_profile = 'cimhub_2023'
cim = importlib.import_module('cimgraph.data_profile.' + cim_profile)

# %%
from cimgraph.databases import ConnectionParameters
from cimgraph.databases.rdflib.rdflib import RDFlibConnection
from cimgraph.models import FeederModel
from cimgraph.models import NodeBreakerModel
from cimgraph.models import BusBranchModel

# %%
cim_profile = 'cimhub_2023'
cim = importlib.import_module('cimgraph.data_profile.' + cim_profile)

# RDFLib File Reader Connection
params = ConnectionParameters(filename="../cimgraph/tests/test_models/ieee13.xml", cim_profile='cimhub_2023', iec61970_301=8)
rdf = RDFlibConnection(params)

feeder_mrid = "49AD8E07-3BF9-A4E2-CB8F-C3722F837B62"
feeder = cim.Feeder(mRID = feeder_mrid)
network = FeederModel(connection=rdf, container=feeder, distributed=False)

# %%
# Get Positions
def get_positions(cim_class):
    network.get_all_edges(cim_class)
    network.get_all_edges(cim.Location)
    network.get_all_edges(cim.PositionPoint)

    for equipment in network.graph[cim_class].values():
        print(equipment.name)
        for point in equipment.Location.PositionPoints:
            print("x = ", point.xPosition)
            print("y = ", point.yPosition )

# %%
get_positions(cim.ACLineSegment) #lines
get_positions(cim.LoadBreakSwitch) #switch
get_positions(cim.PowerTransformer) # transformer
get_positions(cim.LinearShuntCompensator) #capacitor
get_positions(cim.PowerElectronicsConnection) #inverter
# Out:
# 684611
# x =  0
# y =  100
# x =  95
# y =  100
# 684652
# x =  100
# y =  0
# x =  100
# y =  100
# 671684
# x =  200
# y =  100
# x =  100
# y =  100
# 650632
# x =  200
# y =  300
# x =  200
# y =  250
# 632670
# x =  200
# y =  245
# x =  200
# y =  200
# 632633
# x =  200
# y =  250
# x =  350
# y =  250
# 670671
# x =  200
# y =  200
# x =  200
# y =  100
# 671680
# x =  200
# y =  0
# x =  200
# y =  100
# 692675
# x =  250
# y =  100
# x =  400
# y =  100
# 632645
# x =  200
# y =  250
# x =  100
# y =  250
# 645646
# x =  100
# y =  250
# x =  0
# y =  250
# 671692
# x =  250
# y =  100
# x =  200
# y =  100
# sect1
# x =  95
# y =  100
# x =  100
# y =  100
# sub3
# x =  200
# y =  400
# x =  205
# y =  350
# x =  200
# y =  350
# Reg
# x =  200
# y =  300
# x =  200
# y =  325
# xfm1
# x =  390
# y =  250
# x =  400
# y =  250
# tpoletop
# x =  200
# y =  200
# x =  200
# y =  190
# x =  200
# y =  190
# cap1
# x =  400
# y =  100
# cap2
# x =  0
# y =  100
# batidle
# x =  400
# y =  250
# school
# x =  400
# y =  250
# house
# x =  200
# y =  190
# school
# x =  400
# y =  250
# house
# x =  200
# y =  190

# %%
node_positions = {}
network.get_all_edges(cim.ConnectivityNode)
network.get_all_edges(cim.Terminal)

for node in network.graph[cim.ConnectivityNode].values():
    node_positions[node.mRID] = {}
    node_positions[node.mRID]["name"] = node.name

    for terminal in node.Terminals:
        seq = terminal.sequenceNumber
        equipment = terminal.ConductingEquipment
        if equipment.Location is None:
            network.get_all_edges(equipment.__class__)
            network.get_all_edges(cim.Location)
        try:
            for point in equipment.Location.PositionPoints:
                if seq == point.sequenceNumber:
                    node_positions[node.mRID]["x"] = point.xPosition
                    node_positions[node.mRID]["y"] = point.yPosition
        except:
            print("warning: no position")

for pos in node_positions.values():
    print(pos["name"], "x=", pos["x"], "y=", pos["y"])
# Out:
# 611 x= 0 y= 100
# brkr x= 200 y= 325
# 650 x= 200 y= 350
# tap x= 95 y= 100
# 650z x= 205 y= 350
# sourcebus x= 200 y= 400
# 675 x= 400 y= 100
# 652 x= 100 y= 0
# 684 x= 100 y= 100
# house x= 200 y= 190
# 671 x= 200 y= 100
# 634 x= 400 y= 250
# 632 x= 200 y= 250
# rg60 x= 200 y= 300
# mid x= 200 y= 245
# 670 x= 200 y= 200
# 633 x= 350 y= 250
# 692 x= 250 y= 100
# xf1 x= 390 y= 250
# 680 x= 200 y= 0
# 645 x= 100 y= 250
# 646 x= 0 y= 250

# %%
#Fields for editing a class
cim.ACLineSegment.__dataclass_fields__.keys()
# Out:
# dict_keys(['mRID', 'aliasName', 'description', 'name', 'Names', 'AssetDatasheet', 'Assets', 'ConfigurationEvent', 'Controls', 'Location', 'Measurements', 'OperatingShare', 'PSRType', 'ReportingGroup', 'aggregate', 'inService', 'networkAnalysisEnabled', 'normallyInService', 'AdditionalEquipmentContainer', 'EquipmentContainer', 'Faults', 'OperationalLimitSet', 'UsagePoints', 'BaseVoltage', 'SvStatus', 'Terminals', 'length', 'b0ch', 'bch', 'g0ch', 'gch', 'r', 'r0', 'shortCircuitEndTemperature', 'x', 'x0', 'ACLineSegmentPhases', 'Clamp', 'Cut', 'LineFaults', 'ParallelLineSegment', 'PerLengthImpedance', 'WireSpacingInfo'])

# %%
# Dump json of all values
cim_class = cim.ACLineSegment

# network.get_all_edges(cim_class)
network.__dumps__(cim_class, show_empty=True)
# Out:
# {'8E180773-2A9B-4136-BC9A-132A52C8E276': {'mRID': '8E180773-2A9B-4136-BC9A-132A52C8E276',
#   'aliasName': '',
#   'description': '',
#   'name': '684611',
#   'Names': '',
#   'AssetDatasheet': '',
#   'Assets': '',
#   'ConfigurationEvent': '',
#   'Controls': '',
#   'Location': "{'@type': {'Location'}, '@id': {'5A4B421C-35AA-45FA-B364-43236D22BCEE'}}",
#   'Measurements': '',
#   'OperatingShare': '',
#   'PSRType': '',
#   'ReportingGroup': '',
#   'aggregate': '',
#   'inService': '',
#   'networkAnalysisEnabled': '',
#   'normallyInService': '',
#   'AdditionalEquipmentContainer': '',
#   'EquipmentContainer': "{'@type': {'Feeder'}, '@id': {'49AD8E07-3BF9-A4E2-CB8F-C3722F837B62'}}",
#   'Faults': '',
#   'OperationalLimitSet': '',
#   'UsagePoints': '',
#   'BaseVoltage': "{'@type': {'BaseVoltage'}, '@id': {'2A158E0C-CD01-4A50-AEBA-59D761FCF15D'}}",
#   'SvStatus': '',
#   'Terminals': "[{'@type': {'Terminal'}, '@id': {'233304A2-B68B-4EC3-A692-4735DE495569'}}, {'@type': {'Terminal'}, '@id': {'EA5FF2C4-F7E1-436D-BDEC-1C48D4DBB50D'}}]",
#   'length': '91.44',
#   'b0ch': '',
#   'bch': '',
#   'g0ch': '',
#   'gch': '',
#   'r': '',
#   'r0': '',
#   'shortCircuitEndTemperature': '',
#   'x': '',
#   'x0': '',
#   'ACLineSegmentPhases': "[{'@type': {'ACLineSegmentPhase'}, '@id': {'AA2FE477-C2D1-4206-9A8E-742D27976105'}}]",
#   'Clamp': '',
#   'Cut': '',
#   'LineFaults': '',
#   'ParallelLineSegment': '',
#   'PerLengthImpedance': "{'@type': {'PerLengthPhaseImpedance'}, '@id': {'B10FD3C7-8BD6-45D0-9A08-8ADFE7A51952'}}",
#   'WireSpacingInfo': ''},
#  'ABF877D7-DAC2-4BF0-AB58-9A8A02E92EB3': {'mRID': 'ABF877D7-DAC2-4BF0-AB58-9A8A02E92EB3',
#   'aliasName': '',
#   'description': '',
#   'name': '684652',
#   'Names': '',
#   'AssetDatasheet': '',
#   'Assets': '',
#   'ConfigurationEvent': '',
#   'Controls': '',
#   'Location': "{'@type': {'Location'}, '@id': {'CF03D366-44AC-4088-B698-D42F4E39D8C4'}}",
#   'Measurements': '',
#   'OperatingShare': '',
#   'PSRType': '',
#   'ReportingGroup': '',
#   'aggregate': '',
#   'inService': '',
#   'networkAnalysisEnabled': '',
#   'normallyInService': '',
#   'AdditionalEquipmentContainer': '',
#   'EquipmentContainer': "{'@type': {'Feeder'}, '@id': {'49AD8E07-3BF9-A4E2-CB8F-C3722F837B62'}}",
#   'Faults': '',
#   'OperationalLimitSet': '',
#   'UsagePoints': '',
#   'BaseVoltage': "{'@type': {'BaseVoltage'}, '@id': {'2A158E0C-CD01-4A50-AEBA-59D761FCF15D'}}",
#   'SvStatus': '',
#   'Terminals': "[{'@type': {'Terminal'}, '@id': {'8692A804-428A-4637-BD47-69C76F873DAB'}}, {'@type': {'Terminal'}, '@id': {'3313C5A7-ED81-47D3-8114-AD654A5DE21B'}}]",
#   'length': '243.84',
#   'b0ch': '',
#   'bch': '',
#   'g0ch': '',
#   'gch': '',
#   'r': '',
#   'r0': '',
#   'shortCircuitEndTemperature': '',
#   'x': '',
#   'x0': '',
#   'ACLineSegmentPhases': "[{'@type': {'ACLineSegmentPhase'}, '@id': {'D78E30EA-6215-4365-A330-A13FADA79F4F'}}]",
#   'Clamp': '',
#   'Cut': '',
#   'LineFaults': '',
#   'ParallelLineSegment': '',
#   'PerLengthImpedance': "{'@type': {'PerLengthPhaseImpedance'}, '@id': {'B687FB8B-3772-4BC7-9CAD-07497C7004D3'}}",
#   'WireSpacingInfo': ''},
#  'D34B0D01-B082-4081-A3CC-B68B9B8313A4': {'mRID': 'D34B0D01-B082-4081-A3CC-B68B9B8313A4',
#   'aliasName': '',
#   'description': '',
#   'name': '671684',
#   'Names': '',
#   'AssetDatasheet': '',
#   'Assets': '',
#   'ConfigurationEvent': '',
#   'Controls': '',
#   'Location': "{'@type': {'Location'}, '@id': {'58246081-FEDB-4DE7-8173-C408CFE3803E'}}",
#   'Measurements': '',
#   'OperatingShare': '',
#   'PSRType': '',
#   'ReportingGroup': '',
#   'aggregate': '',
#   'inService': '',
#   'networkAnalysisEnabled': '',
#   'normallyInService': '',
#   'AdditionalEquipmentContainer': '',
#   'EquipmentContainer': "{'@type': {'Feeder'}, '@id': {'49AD8E07-3BF9-A4E2-CB8F-C3722F837B62'}}",
#   'Faults': '',
#   'OperationalLimitSet': '',
#   'UsagePoints': '',
#   'BaseVoltage': "{'@type': {'BaseVoltage'}, '@id': {'2A158E0C-CD01-4A50-AEBA-59D761FCF15D'}}",
#   'SvStatus': '',
#   'Terminals': "[{'@type': {'Terminal'}, '@id': {'A4C58654-2972-4A3E-AE65-3868941DA037'}}, {'@type': {'Terminal'}, '@id': {'BC623628-BD23-4A1A-A406-15CA63556149'}}]",
#   'length': '91.44',
#   'b0ch': '',
#   'bch': '',
#   'g0ch': '',
#   'gch': '',
#   'r': '',
#   'r0': '',
#   'shortCircuitEndTemperature': '',
#   'x': '',
#   'x0': '',
#   'ACLineSegmentPhases': "[{'@type': {'ACLineSegmentPhase'}, '@id': {'5143B56C-5AF7-4D47-A6B1-5F952B891190'}}, {'@type': {'ACLineSegmentPhase'}, '@id': {'22182853-3560-4EE4-8BA2-0730C5F5AF94'}}]",
#   'Clamp': '',
#   'Cut': '',
#   'LineFaults': '',
#   'ParallelLineSegment': '',
#   'PerLengthImpedance': "{'@type': {'PerLengthPhaseImpedance'}, '@id': {'D3933951-0672-4817-B38D-E51F47E8631F'}}",
#   'WireSpacingInfo': ''},
#  'A04CDFB1-E951-4FC4-8882-0323CD70AE3C': {'mRID': 'A04CDFB1-E951-4FC4-8882-0323CD70AE3C',
#   'aliasName': '',
#   'description': '',
#   'name': '650632',
#   'Names': '',
#   'AssetDatasheet': '',
#   'Assets': '',
#   'ConfigurationEvent': '',
#   'Controls': '',
#   'Location': "{'@type': {'Location'}, '@id': {'3A63B621-3FA6-4805-96F9-DD57A7F88ACF'}}",
#   'Measurements': '',
#   'OperatingShare': '',
#   'PSRType': '',
#   'ReportingGroup': '',
#   'aggregate': '',
#   'inService': '',
#   'networkAnalysisEnabled': '',
#   'normallyInService': '',
#   'AdditionalEquipmentContainer': '',
#   'EquipmentContainer': "{'@type': {'Feeder'}, '@id': {'49AD8E07-3BF9-A4E2-CB8F-C3722F837B62'}}",
#   'Faults': '',
#   'OperationalLimitSet': '',
#   'UsagePoints': '',
#   'BaseVoltage': "{'@type': {'BaseVoltage'}, '@id': {'2A158E0C-CD01-4A50-AEBA-59D761FCF15D'}}",
#   'SvStatus': '',
#   'Terminals': "[{'@type': {'Terminal'}, '@id': {'3589A9BE-F3BE-45C3-B84E-3CE5B6105D11'}}, {'@type': {'Terminal'}, '@id': {'000BA1F2-6879-47D7-826D-3CACD23EE20B'}}]",
#   'length': '609.6',
#   'b0ch': '',
#   'bch': '',
#   'g0ch': '',
#   'gch': '',
#   'r': '',
#   'r0': '',
#   'shortCircuitEndTemperature': '',
#   'x': '',
#   'x0': '',
#   'ACLineSegmentPhases': "[{'@type': {'ACLineSegmentPhase'}, '@id': {'2D60B241-DE87-48BD-A8D3-FE4B705B40ED'}}, {'@type': {'ACLineSegmentPhase'}, '@id': {'A66508A9-C9C1-4DB5-8FFD-F081E5E9E14D'}}, {'@type': {'ACLineSegmentPhase'}, '@id': {'2A5A1025-AD81-4BFA-A7F0-ED70F7F43DAA'}}]",
#   'Clamp': '',
#   'Cut': '',
#   'LineFaults': '',
#   'ParallelLineSegment': '',
#   'PerLengthImpedance': "{'@type': {'PerLengthPhaseImpedance'}, '@id': {'50044320-7295-4591-B39E-F793F1923098'}}",
#   'WireSpacingInfo': ''},
#  'ABF53597-A808-422A-B7EE-552F24D83A5F': {'mRID': 'ABF53597-A808-422A-B7EE-552F24D83A5F',
#   'aliasName': '',
#   'description': '',
#   'name': '632670',
#   'Names': '',
#   'AssetDatasheet': '',
#   'Assets': '',
#   'ConfigurationEvent': '',
#   'Controls': '',
#   'Location': "{'@type': {'Location'}, '@id': {'216C1943-900F-4939-92FE-A3A4817363D8'}}",
#   'Measurements': '',
#   'OperatingShare': '',
#   'PSRType': '',
#   'ReportingGroup': '',
#   'aggregate': '',
#   'inService': '',
#   'networkAnalysisEnabled': '',
#   'normallyInService': '',
#   'AdditionalEquipmentContainer': '',
#   'EquipmentContainer': "{'@type': {'Feeder'}, '@id': {'49AD8E07-3BF9-A4E2-CB8F-C3722F837B62'}}",
#   'Faults': '',
#   'OperationalLimitSet': '',
#   'UsagePoints': '',
#   'BaseVoltage': "{'@type': {'BaseVoltage'}, '@id': {'2A158E0C-CD01-4A50-AEBA-59D761FCF15D'}}",
#   'SvStatus': '',
#   'Terminals': "[{'@type': {'Terminal'}, '@id': {'5EDB2918-D669-457C-9F44-E08EBA5AC850'}}, {'@type': {'Terminal'}, '@id': {'B554744A-F5B5-485C-B67E-2487A8740295'}}]",
#   'length': '203.3016',
#   'b0ch': '',
#   'bch': '',
#   'g0ch': '',
#   'gch': '',
#   'r': '',
#   'r0': '',
#   'shortCircuitEndTemperature': '',
#   'x': '',
#   'x0': '',
#   'ACLineSegmentPhases': "[{'@type': {'ACLineSegmentPhase'}, '@id': {'4894C0CB-632C-454A-B9A2-1C2E41FB25FF'}}, {'@type': {'ACLineSegmentPhase'}, '@id': {'28DAC6BE-8DD5-4C61-958E-ADB4E8A91EF8'}}, {'@type': {'ACLineSegmentPhase'}, '@id': {'CF8E1FD4-BF1D-49B6-905C-8D0F9587FEF7'}}]",
#   'Clamp': '',
#   'Cut': '',
#   'LineFaults': '',
#   'ParallelLineSegment': '',
#   'PerLengthImpedance': "{'@type': {'PerLengthPhaseImpedance'}, '@id': {'50044320-7295-4591-B39E-F793F1923098'}}",
#   'WireSpacingInfo': ''},
#  'FBE26B35-13AB-457D-9795-DF58B28E309D': {'mRID': 'FBE26B35-13AB-457D-9795-DF58B28E309D',
#   'aliasName': '',
#   'description': '',
#   'name': '632633',
#   'Names': '',
#   'AssetDatasheet': '',
#   'Assets': '',
#   'ConfigurationEvent': '',
#   'Controls': '',
#   'Location': "{'@type': {'Location'}, '@id': {'3D3B02A5-E9D5-45F0-9506-22B098EDA261'}}",
#   'Measurements': '',
#   'OperatingShare': '',
#   'PSRType': '',
#   'ReportingGroup': '',
#   'aggregate': '',
#   'inService': '',
#   'networkAnalysisEnabled': '',
#   'normallyInService': '',
#   'AdditionalEquipmentContainer': '',
#   'EquipmentContainer': "{'@type': {'Feeder'}, '@id': {'49AD8E07-3BF9-A4E2-CB8F-C3722F837B62'}}",
#   'Faults': '',
#   'OperationalLimitSet': '',
#   'UsagePoints': '',
#   'BaseVoltage': "{'@type': {'BaseVoltage'}, '@id': {'2A158E0C-CD01-4A50-AEBA-59D761FCF15D'}}",
#   'SvStatus': '',
#   'Terminals': "[{'@type': {'Terminal'}, '@id': {'F0E10483-D8AD-46BE-AF5F-08228955796B'}}, {'@type': {'Terminal'}, '@id': {'A6C57C2E-A084-4701-ADF5-FB6F3E36F45C'}}]",
#   'length': '152.4',
#   'b0ch': '',
#   'bch': '',
#   'g0ch': '',
#   'gch': '',
#   'r': '',
#   'r0': '',
#   'shortCircuitEndTemperature': '',
#   'x': '',
#   'x0': '',
#   'ACLineSegmentPhases': "[{'@type': {'ACLineSegmentPhase'}, '@id': {'18F23724-C3EE-498E-96A7-98FE210A523C'}}, {'@type': {'ACLineSegmentPhase'}, '@id': {'30E5A294-2F25-480D-BDDA-777F59ED5AF3'}}, {'@type': {'ACLineSegmentPhase'}, '@id': {'5830B397-557C-41B5-A94D-95A3841505D0'}}]",
#   'Clamp': '',
#   'Cut': '',
#   'LineFaults': '',
#   'ParallelLineSegment': '',
#   'PerLengthImpedance': "{'@type': {'PerLengthPhaseImpedance'}, '@id': {'EAEF5A85-027A-4BE2-9A07-99D4550C3DE1'}}",
#   'WireSpacingInfo': ''},
#  '45395C84-F20A-4F5A-977F-B80348256421': {'mRID': '45395C84-F20A-4F5A-977F-B80348256421',
#   'aliasName': '',
#   'description': '',
#   'name': '670671',
#   'Names': '',
#   'AssetDatasheet': '',
#   'Assets': '',
#   'ConfigurationEvent': '',
#   'Controls': '',
#   'Location': "{'@type': {'Location'}, '@id': {'BE71BF98-CD79-4A6D-804B-6729A6EB8020'}}",
#   'Measurements': '',
#   'OperatingShare': '',
#   'PSRType': '',
#   'ReportingGroup': '',
#   'aggregate': '',
#   'inService': '',
#   'networkAnalysisEnabled': '',
#   'normallyInService': '',
#   'AdditionalEquipmentContainer': '',
#   'EquipmentContainer': "{'@type': {'Feeder'}, '@id': {'49AD8E07-3BF9-A4E2-CB8F-C3722F837B62'}}",
#   'Faults': '',
#   'OperationalLimitSet': '',
#   'UsagePoints': '',
#   'BaseVoltage': "{'@type': {'BaseVoltage'}, '@id': {'2A158E0C-CD01-4A50-AEBA-59D761FCF15D'}}",
#   'SvStatus': '',
#   'Terminals': "[{'@type': {'Terminal'}, '@id': {'EEF69C71-5A87-4378-8DF4-4578635C81B4'}}, {'@type': {'Terminal'}, '@id': {'092A5199-DB5E-419E-ADCF-53B290EFAB2C'}}]",
#   'length': '406.2984',
#   'b0ch': '',
#   'bch': '',
#   'g0ch': '',
#   'gch': '',
#   'r': '',
#   'r0': '',
#   'shortCircuitEndTemperature': '',
#   'x': '',
#   'x0': '',
#   'ACLineSegmentPhases': "[{'@type': {'ACLineSegmentPhase'}, '@id': {'5AFA6BC8-9FCE-4931-A83B-C8CA2EC15551'}}, {'@type': {'ACLineSegmentPhase'}, '@id': {'E295A13C-1B49-4D5A-8BB6-6D106AE0D436'}}, {'@type': {'ACLineSegmentPhase'}, '@id': {'5092EC91-3F74-4829-ABF1-AF5C6AFD1A50'}}]",
#   'Clamp': '',
#   'Cut': '',
#   'LineFaults': '',
#   'ParallelLineSegment': '',
#   'PerLengthImpedance': "{'@type': {'PerLengthPhaseImpedance'}, '@id': {'50044320-7295-4591-B39E-F793F1923098'}}",
#   'WireSpacingInfo': ''},
#  '4C04F838-62AA-475E-AEFA-A63B7C889C13': {'mRID': '4C04F838-62AA-475E-AEFA-A63B7C889C13',
#   'aliasName': '',
#   'description': '',
#   'name': '671680',
#   'Names': '',
#   'AssetDatasheet': '',
#   'Assets': '',
#   'ConfigurationEvent': '',
#   'Controls': '',
#   'Location': "{'@type': {'Location'}, '@id': {'6E6EDB91-07A8-46E9-BDC5-733EAB0552F7'}}",
#   'Measurements': '',
#   'OperatingShare': '',
#   'PSRType': '',
#   'ReportingGroup': '',
#   'aggregate': '',
#   'inService': '',
#   'networkAnalysisEnabled': '',
#   'normallyInService': '',
#   'AdditionalEquipmentContainer': '',
#   'EquipmentContainer': "{'@type': {'Feeder'}, '@id': {'49AD8E07-3BF9-A4E2-CB8F-C3722F837B62'}}",
#   'Faults': '',
#   'OperationalLimitSet': '',
#   'UsagePoints': '',
#   'BaseVoltage': "{'@type': {'BaseVoltage'}, '@id': {'2A158E0C-CD01-4A50-AEBA-59D761FCF15D'}}",
#   'SvStatus': '',
#   'Terminals': "[{'@type': {'Terminal'}, '@id': {'8BE8D3EA-EEE9-406C-B24C-B169C8EC799A'}}, {'@type': {'Terminal'}, '@id': {'FF3DE145-0066-4C1F-867C-2A2BF3012EDF'}}]",
#   'length': '304.8',
#   'b0ch': '',
#   'bch': '',
#   'g0ch': '',
#   'gch': '',
#   'r': '',
#   'r0': '',
#   'shortCircuitEndTemperature': '',
#   'x': '',
#   'x0': '',
#   'ACLineSegmentPhases': "[{'@type': {'ACLineSegmentPhase'}, '@id': {'A539F769-AF0F-4203-99CE-6FF4B9D07F70'}}, {'@type': {'ACLineSegmentPhase'}, '@id': {'1B6C674F-B22C-4D39-9294-98BB4634ED96'}}, {'@type': {'ACLineSegmentPhase'}, '@id': {'A28877AB-3D74-4950-AA8C-45D962BD7331'}}]",
#   'Clamp': '',
#   'Cut': '',
#   'LineFaults': '',
#   'ParallelLineSegment': '',
#   'PerLengthImpedance': "{'@type': {'PerLengthPhaseImpedance'}, '@id': {'50044320-7295-4591-B39E-F793F1923098'}}",
#   'WireSpacingInfo': ''},
#  '7060D0BB-B30D-4932-8FA1-40820A0FC4D0': {'mRID': '7060D0BB-B30D-4932-8FA1-40820A0FC4D0',
#   'aliasName': '',
#   'description': '',
#   'name': '692675',
#   'Names': '',
#   'AssetDatasheet': '',
#   'Assets': '',
#   'ConfigurationEvent': '',
#   'Controls': '',
#   'Location': "{'@type': {'Location'}, '@id': {'F302E764-FCD7-41AF-903E-42A4F0045EEF'}}",
#   'Measurements': '',
#   'OperatingShare': '',
#   'PSRType': '',
#   'ReportingGroup': '',
#   'aggregate': '',
#   'inService': '',
#   'networkAnalysisEnabled': '',
#   'normallyInService': '',
#   'AdditionalEquipmentContainer': '',
#   'EquipmentContainer': "{'@type': {'Feeder'}, '@id': {'49AD8E07-3BF9-A4E2-CB8F-C3722F837B62'}}",
#   'Faults': '',
#   'OperationalLimitSet': '',
#   'UsagePoints': '',
#   'BaseVoltage': "{'@type': {'BaseVoltage'}, '@id': {'2A158E0C-CD01-4A50-AEBA-59D761FCF15D'}}",
#   'SvStatus': '',
#   'Terminals': "[{'@type': {'Terminal'}, '@id': {'CD147977-45B7-48AD-9F72-4F488BD6AD6D'}}, {'@type': {'Terminal'}, '@id': {'B4E1784C-5500-47AE-958B-A286CE8C17A5'}}]",
#   'length': '152.4',
#   'b0ch': '',
#   'bch': '',
#   'g0ch': '',
#   'gch': '',
#   'r': '',
#   'r0': '',
#   'shortCircuitEndTemperature': '',
#   'x': '',
#   'x0': '',
#   'ACLineSegmentPhases': "[{'@type': {'ACLineSegmentPhase'}, '@id': {'5D4FC857-8FD9-4BE9-8C1F-11CF7E38AA46'}}, {'@type': {'ACLineSegmentPhase'}, '@id': {'216C7BCA-22B0-4B68-81F5-33AB8A4E6DA7'}}, {'@type': {'ACLineSegmentPhase'}, '@id': {'BD4212B3-1635-421A-BDD8-767B6738FA80'}}]",
#   'Clamp': '',
#   'Cut': '',
#   'LineFaults': '',
#   'ParallelLineSegment': '',
#   'PerLengthImpedance': "{'@type': {'PerLengthPhaseImpedance'}, '@id': {'07097405-6433-4EBF-9EE2-2049906B4157'}}",
#   'WireSpacingInfo': ''},
#  '1C6781A2-5B9D-4525-8A9B-F9B32C4C4AC0': {'mRID': '1C6781A2-5B9D-4525-8A9B-F9B32C4C4AC0',
#   'aliasName': '',
#   'description': '',
#   'name': '632645',
#   'Names': '',
#   'AssetDatasheet': '',
#   'Assets': '',
#   'ConfigurationEvent': '',
#   'Controls': '',
#   'Location': "{'@type': {'Location'}, '@id': {'E85D20C3-84EA-43F6-9D31-5239FAB00019'}}",
#   'Measurements': '',
#   'OperatingShare': '',
#   'PSRType': '',
#   'ReportingGroup': '',
#   'aggregate': '',
#   'inService': '',
#   'networkAnalysisEnabled': '',
#   'normallyInService': '',
#   'AdditionalEquipmentContainer': '',
#   'EquipmentContainer': "{'@type': {'Feeder'}, '@id': {'49AD8E07-3BF9-A4E2-CB8F-C3722F837B62'}}",
#   'Faults': '',
#   'OperationalLimitSet': '',
#   'UsagePoints': '',
#   'BaseVoltage': "{'@type': {'BaseVoltage'}, '@id': {'2A158E0C-CD01-4A50-AEBA-59D761FCF15D'}}",
#   'SvStatus': '',
#   'Terminals': "[{'@type': {'Terminal'}, '@id': {'4891537F-4088-48F5-9B1A-8294D50901E4'}}, {'@type': {'Terminal'}, '@id': {'A563A3A5-EA39-4998-96B2-538227E2D2F6'}}]",
#   'length': '152.4',
#   'b0ch': '',
#   'bch': '',
#   'g0ch': '',
#   'gch': '',
#   'r': '',
#   'r0': '',
#   'shortCircuitEndTemperature': '',
#   'x': '',
#   'x0': '',
#   'ACLineSegmentPhases': "[{'@type': {'ACLineSegmentPhase'}, '@id': {'19B6044B-6915-4245-9DD1-6AB0444D42A6'}}, {'@type': {'ACLineSegmentPhase'}, '@id': {'D9C9CEA6-B3F0-4E02-9911-3DFA192B4D01'}}]",
#   'Clamp': '',
#   'Cut': '',
#   'LineFaults': '',
#   'ParallelLineSegment': '',
#   'PerLengthImpedance': "{'@type': {'PerLengthPhaseImpedance'}, '@id': {'12C526C5-6645-4C0C-83CD-3030C440DA17'}}",
#   'WireSpacingInfo': ''},
#  '0BBD0EA3-F665-465B-86FD-FC8B8466AD53': {'mRID': '0BBD0EA3-F665-465B-86FD-FC8B8466AD53',
#   'aliasName': '',
#   'description': '',
#   'name': '645646',
#   'Names': '',
#   'AssetDatasheet': '',
#   'Assets': '',
#   'ConfigurationEvent': '',
#   'Controls': '',
#   'Location': "{'@type': {'Location'}, '@id': {'89C21411-D107-454A-93B0-0905893DD27D'}}",
#   'Measurements': '',
#   'OperatingShare': '',
#   'PSRType': '',
#   'ReportingGroup': '',
#   'aggregate': '',
#   'inService': '',
#   'networkAnalysisEnabled': '',
#   'normallyInService': '',
#   'AdditionalEquipmentContainer': '',
#   'EquipmentContainer': "{'@type': {'Feeder'}, '@id': {'49AD8E07-3BF9-A4E2-CB8F-C3722F837B62'}}",
#   'Faults': '',
#   'OperationalLimitSet': '',
#   'UsagePoints': '',
#   'BaseVoltage': "{'@type': {'BaseVoltage'}, '@id': {'2A158E0C-CD01-4A50-AEBA-59D761FCF15D'}}",
#   'SvStatus': '',
#   'Terminals': "[{'@type': {'Terminal'}, '@id': {'F3C0F2D0-4D28-49B5-A920-37409B99229D'}}, {'@type': {'Terminal'}, '@id': {'D02B9E99-3557-48F5-B475-4871E47D08F6'}}]",
#   'length': '91.44',
#   'b0ch': '',
#   'bch': '',
#   'g0ch': '',
#   'gch': '',
#   'r': '',
#   'r0': '',
#   'shortCircuitEndTemperature': '',
#   'x': '',
#   'x0': '',
#   'ACLineSegmentPhases': "[{'@type': {'ACLineSegmentPhase'}, '@id': {'CE2AFB05-A1B1-4082-B4EB-2AD8A1D3422D'}}, {'@type': {'ACLineSegmentPhase'}, '@id': {'94FCAFFF-E5F7-4F97-B697-35C46656EDCA'}}]",
#   'Clamp': '',
#   'Cut': '',
#   'LineFaults': '',
#   'ParallelLineSegment': '',
#   'PerLengthImpedance': "{'@type': {'PerLengthPhaseImpedance'}, '@id': {'12C526C5-6645-4C0C-83CD-3030C440DA17'}}",
#   'WireSpacingInfo': ''}}

# %%
# Edit one value -- this would be invoked from viz
line_id = '4C04F838-62AA-475E-AEFA-A63B7C889C13'

line = network.graph[cim.ACLineSegment][line_id]

line.r = 0.004
line.x = 0.010
line.description = "new line description"
