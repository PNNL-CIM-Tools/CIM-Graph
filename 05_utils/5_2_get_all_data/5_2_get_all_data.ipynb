# %% [markdown]
# # Get All Data Shortcuts

# %%
from mermaid import Mermaid

# %%
text = '''zenuml
    title get_all_line_data(network)
    @Actor User
    @AzureFunction utils
    @PubSub GraphModel
    @AzureBackup Database
   
    
    User -> utils.get_all_line_data(network) {
        GraphModel.get_all_edges(cim.ACLineSegment) {
            Database.query {
                return objects
            }  
        }
        GraphModel.get_all_edges(cim.ACLineSegmentPhase) {
            Database.query {
                return objects
            }
        }
        GraphModel.get_all_edges(cim.PhaseImpedanceData) {
            Database.query {
                return objects
            }
        }
    }
'''

# %% [markdown]
# ```
# zenuml
#     title get_all_line_data(network)
#     @Actor User
#     @AzureFunction utils
#     @PubSub GraphModel
#     @AzureBackup Database
#
#
#     User -> utils.get_all_line_data(network) {
#         GraphModel.get_all_edges(cim.ACLineSegment) {
#             Database.query {
#                 return objects
#             }
#         }
#         GraphModel.get_all_edges(cim.ACLineSegmentPhase) {
#             Database.query {
#                 return objects
#             }
#         }
#         GraphModel.get_all_edges(cim.PhaseImpedanceData) {
#             Database.query {
#                 return objects
#             }
#         }
#     }
# ```

# %%
Mermaid(text)
# Out:
#         <div class="mermaid-6a1850ab-5e1f-4fa0-b995-fd61c2cfae48"></div>
#         <script type="module">
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1.0/+esm'
#             const graphDefinition = 'zenuml\n    title get_all_line_data(network)\n    @Actor User\n    @AzureFunction utils\n    @PubSub GraphModel\n    @AzureBackup Database\n   \n    \n    User -> utils.get_all_line_data(network) {\n        GraphModel.get_all_edges(cim.ACLineSegment) {\n            Database.query {\n                return objects\n            }  \n        }\n        GraphModel.get_all_edges(cim.ACLineSegmentPhase) {\n            Database.query {\n                return objects\n            }\n        }\n        GraphModel.get_all_edges(cim.PhaseImpedanceData) {\n            Database.query {\n                return objects\n            }\n        }\n    }\n';
#             const element = document.querySelector('.mermaid-6a1850ab-5e1f-4fa0-b995-fd61c2cfae48');
#             const { svg } = await mermaid.render('graphDiv-6a1850ab-5e1f-4fa0-b995-fd61c2cfae48', graphDefinition);
#             element.innerHTML = svg;
#         </script>
